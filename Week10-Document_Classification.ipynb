# %% [markdown]
# # Assignment Week 10 – Document Classification

# %% [markdown]
# ### Betsy Rosalen and Mikhail Groysman

# %% [markdown]
# ## Project Overview

# %% [markdown]
# It can be useful to be able to classify new "test" documents using already classified "training" documents.  A common example is using a corpus of labeled spam and ham (non-spam) e-mails to predict whether or not a new document is spam.  Here is one example of such data: [UCI Machine Learning Repository: Spambase Data Set](http://archive.ics.uci.edu/ml/datasets/Spambase)
#
# For this project, you can either use the above dataset to predict the class of new documents (either withheld from the training dataset or from another source such as your own spam folder).
#
# For more adventurous students, you are welcome (encouraged!) to come up a different set of documents (including scraped web pages!?) that have already been classified (e.g. tagged), then analyze these documents to predict how new documents should be classified.
#
# This assignment is due end of day on Monday 11/11.
#
# NOTE: This is a two week assignment.

# %% [markdown]
# ## Choosing Documents for Classification

# %% [markdown]
# Let's look at available texts in the guttenberg corpus.

# %%
import nltk
import random
random.seed(250)
import pandas as pd
pd.set_option('display.max_rows', 500)

nltk.corpus.gutenberg.fileids()
# Out:
# ['austen-emma.txt',
#  'austen-persuasion.txt',
#  'austen-sense.txt',
#  'bible-kjv.txt',
#  'blake-poems.txt',
#  'bryant-stories.txt',
#  'burgess-busterbrown.txt',
#  'carroll-alice.txt',
#  'chesterton-ball.txt',
#  'chesterton-brown.txt',
#  'chesterton-thursday.txt',
#  'edgeworth-parents.txt',
#  'melville-moby_dick.txt',
#  'milton-paradise.txt',
#  'shakespeare-caesar.txt',
#  'shakespeare-hamlet.txt',
#  'shakespeare-macbeth.txt',
#  'whitman-leaves.txt']

# %% [markdown]
# We have 3 books by Jane Austen, Bible, 1 book by Blake, and so on. Each author writes using his/her own style. Can we use samples of their work to predict who wrote specific passage?

# %% [markdown]
# ## Austen vs Blake
#
# ### Create texts

# %% [markdown]
# First we need to take all three of Austen's works and combine them to create one text.  We will also remove punctuation and convert everything to lowercase to eliminate duplicate words.  Then we can take that and create a list of text segments.  Each segment will have a length of 1000 words.

# %%
austen = nltk.corpus.gutenberg.words('austen-emma.txt')+nltk.corpus.gutenberg.words('austen-persuasion.txt')+nltk.corpus.gutenberg.words('austen-sense.txt')
austen = [word.lower() for word in austen if word.isalpha()]
austen1=[]
for i in range(366):
    austen1.append([austen[i*1000:(i+1)*1000],'au'])
len(austen)
# Out:
# 366454

# %%
len(austen1)
# Out:
# 366

# %% [markdown]
# We now have a list of 432 1000-word segments of text written by Jane Austen.
#
# We will skip the Bible since it was written by many different authors using many different styles, but let's take the next text in the guttenburg corpus, poems by Blake, and do the same thing we did with Austen.

# %%
blake = nltk.corpus.gutenberg.words('blake-poems.txt')
blake = [word.lower() for word in blake if word.isalpha()]
blake1=[]
for i in range(7):
    blake1.append([blake[i*990:(i+1)*990],'bl'])
len(blake)
# Out:
# 6934

# %% [markdown]
# Since there are just shy of 7000 words total in the Blake text, we will make each segment 990 words in order to get 7 equal segments for Blake.

# %%
len(blake1)
# Out:
# 7

# %% [markdown]
# We now have a list of seven 990-word segments of text written by William Blake.
#
# ### Create Feature Extractor
#
# Now let's take the two original lists of words and combine them to create one longer list and find the 2000 most frequent words, which we will later use to create a feature list for our classifier.

# %%
ab=austen+blake
all_words = nltk.FreqDist(w.lower() for w in ab)
word_features = list(all_words)[:2000] 

wlist = []
for i in range(0, 2000, 200):
    df = pd.DataFrame(word_features[i:(i+200)])
    df.columns=['200 words']
    wlist.append(df)

pd.concat(wlist, axis=1)
# Out:
#          200 words        200 words       200 words        200 words  \
# 0             emma            after            wish        beautiful
# 1               by           dinner      impossible        moonlight
# 2             jane            usual          things             mild
# 3           austen             then            till             draw
# 4           volume             only           awoke             back
# 5                i              sit            made             fire
# 6          chapter             lost       necessary            found
# 7        woodhouse            event        cheerful             damp
# 8         handsome            every         spirits            dirty
# 9           clever          promise        required            catch
# 10             and        happiness         support             cold
# 11            rich           weston         nervous             look
# 12            with              man          easily            shoes
# 13               a  unexceptionable       depressed            speck
# 14     comfortable        character            used            quite
# 15            home             easy          hating       surprising
# 16           happy          fortune            part             vast
# 17     disposition         suitable            kind             rain
# 18          seemed              age          origin           rained
# 19              to         pleasant      reconciled       dreadfully
# 20           unite          manners        daughter             hard
# 21            some            there        marrying        breakfast
# 22              of     satisfaction             nor           wanted
# 23             the      considering            ever              bye
# 24            best             self      compassion              joy
# 25       blessings          denying        entirely             sort
# 26       existence         generous            when          feeling
# 27             had       friendship         obliged            hurry
# 28           lived           always     selfishness  congratulations
# 29          nearly           wished            able             hope
# 30          twenty         promoted         suppose             went
# 31             one            match            feel           behave
# 32           years            black     differently            cried
# 33              in          morning        disposed               ah
# 34           world             work            done              tis
# 35            very             want             sad         business
# 36          little            would           thing           please
# 37        distress               be            deal         possibly
# 38              or             felt         happier           regard
# 39             vex             hour              if            comes
# 40             her         recalled           spent         question
# 41             she             past            rest       dependence
# 42             was         kindness          smiled     independence
# 43        youngest              how         chatted             rate
# 44             two           taught      cheerfully           better
# 45       daughters           played            keep       especially
# 46            most             five        thoughts            those
# 47    affectionate              old             tea         fanciful
# 48       indulgent          devoted             say      troublesome
# 49          father           powers         exactly         creature
# 50     consequence           attach            said        playfully
# 51          sister            amuse            poor             head
# 52               s           health            pity        certainly
# 53        marriage           nursed              is          believe
# 54            been          through          cannot        sometimes
# 55        mistress          various           agree          dearest
# 56             his        illnesses             you             mean
# 57           house        childhood            papa         horrible
# 58            from            large            know             idea
# 59           early             debt            good               oh
# 60          period        gratitude        humoured            meant
# 61          mother            owing      thoroughly           myself
# 62            died             here        deserves            loves
# 63             too      intercourse            wife             joke
# 64            long             last            live          another
# 65             ago            seven              us             fact
# 66             for            equal              my           faults
# 67            have          footing             odd             told
# 68            more          perfect         humours        agreeable
# 69            than        unreserve           might             knew
# 70              an             soon           where          suspect
# 71      indistinct         followed       advantage            knows
# 72     remembrance         isabella           three          flatter
# 73        caresses            their           times       reflection
# 74           place             each            dear              has
# 75        supplied            other           often          persons
# 76       excellent              yet              we          chances
# 77           woman           dearer           shall           gainer
# 78              as         tenderer             see          willing
# 79       governess     recollection          coming              let
# 80             who        companion         meeting             pass
# 81          fallen             such           begin             hear
# 82           short              few              go          behaved
# 83       affection        possessed             pay       charmingly
# 84         sixteen      intelligent              am         punctual
# 85            miss         informed             get            looks
# 86          taylor           useful             far             tear
# 87              mr          knowing        randalls             face
# 88          family             ways        distance             seen
# 89            less       interested            walk            apart
# 90          friend              its          nobody            bears
# 91            fond         concerns            your            sorry
# 92            both       peculiarly         walking             lose
# 93             but         pleasure        carriage           thinks
# 94    particularly           scheme            sure           turned
# 95         between             hers           james          divided
# 96              it             whom            will            tears
# 97        intimacy            could            like           smiles
# 98         sisters            speak             put           should
# 99            even            arose          horses       acceptable
# 100         before            never             are        important
# 101         ceased             find           while           secure
# 102           hold            fault          paying        provision
# 103        nominal             bear             our        therefore
# 104         office           change            into            allow
# 105       mildness             true          stable             pain
# 106         temper            going         already          happily
# 107         hardly             half          talked        forgotten
# 108        allowed             mile           night           matter
# 109         impose             them             may     considerable
# 110            any            aware         because             four
# 111      restraint            great       housemaid           proved
# 112         shadow             must           doubt            marry
# 113      authority       difference         whether            shook
# 114          being              mrs            take           fondly
# 115            now       advantages        anywhere          replied
# 116         passed          natural            else          matches
# 117           away         domestic             got         foretell
# 118           they        suffering          hannah         whatever
# 119         living     intellectual       mentioned             pray
# 120       together         solitude            glad             none
# 121       mutually           dearly           lucky         greatest
# 122       attached            loved        slighted        amusement
# 123          doing               he            upon          success
# 124           just             meet         account          widower
# 125           what     conversation            make        perfectly
# 126          liked         rational         servant       constantly
# 127         highly          playful          pretty         occupied
# 128      esteeming             evil          spoken           either
# 129       judgment           actual            girl          friends
# 130       directed        disparity         opinion         wherever
# 131        chiefly             ages        whenever             need
# 132            own        increased        curtseys            spend
# 133           real     constitution            asks           single
# 134          evils           habits              me             year
# 135         indeed   valetudinarian              do            alone
# 136      situation             life          manner         deathbed
# 137           were          without      needlework           others
# 138          power         activity         observe              son
# 139         having             mind           turns            uncle
# 140         rather             body            lock          letting
# 141           much            older            door           solemn
# 142            way           though           right         nonsense
# 143          think       everywhere           bangs          subject
# 144           well     friendliness         comfort         believed
# 145        herself            heart        somebody            since
# 146          these          amiable           about              met
# 147  disadvantages          talents            goes         broadway
# 148          which      recommended         hearing             lane
# 149     threatened              him            tell            began
# 150          alloy             time          spared          drizzle
# 151           many    comparatively       exertions           darted
# 152     enjoyments          removed        maintain        gallantry
# 153         danger        matrimony            flow         borrowed
# 154        however          settled           ideas        umbrellas
# 155             at           london           hoped           farmer
# 156        present            miles            help         mitchell
# 157             so              off      backgammon          planned
# 158    unperceived           beyond       tolerably          blessed
# 159           that            daily        attacked         instance
# 160            did            reach         regrets            leave
# 161            not          october           table           making
# 162          means         november          placed       understand
# 163           rank        struggled         visitor         supposes
# 164    misfortunes        hartfield     immediately        endeavour
# 165         sorrow        christmas      afterwards         properly
# 166           came             next          walked       delicately
# 167         gentle            visit     unnecessary     endeavouring
# 168            all          husband       knightley            bring
# 169          shape         children        sensible           worthy
# 170   disagreeable             fill           eight       employment
# 171  consciousness             give          thirty            young
# 172        married          society        intimate             lady
# 173           loss            again       connected          imagine
# 174          first         highbury           elder         planning
# 175        brought         populous         brother           saying
# 176          grief          village        frequent         yourself
# 177             on           almost         welcome             idle
# 178        wedding        amounting        directly              why
# 179            day             town          mutual             talk
# 180           this            spite      connexions            merit
# 181        beloved         separate        returned            proud
# 182            sat             lawn            late            guess
# 183       mournful      shrubberies            days              can
# 184        thought             name         absence            known
# 185    continuance           really       brunswick          triumph
# 186           over           belong          square         cleverer
# 187          bride         afforded    circumstance           depend
# 188         people           equals        animated           merely
# 189           gone       woodhouses       inquiries             luck
# 190           left           looked        answered           talent
# 191           dine               up  satisfactorily             word
# 192             no     acquaintance      gratefully          quarrel
# 193       prospect      universally        observed            claim
# 194          third            civil            come            drawn
# 195          cheer            among             out         pictures
# 196        evening         accepted            call        something
# 197       composed             lieu          afraid          nothing
# 198        himself       melancholy        shocking           visits
# 199          sleep             sigh             sir            given
#
#            200 words          200 words        200 words      200 words  \
# 0     encouragements             avowed             hate          moved
# 1           smoothed           adoption          outward       forwards
# 2            matters             assume          boasted       alacrity
# 3             enough           unlikely           beauty        impulse
# 4         comprehend         assistance       cleverness    indifferent
# 5    straightforward       apprehension      distinction         credit
# 6               open               aunt           middle    attentively
# 7            hearted         capricious          failing        honours
# 8         unaffected           governed         possible           meal
# 9             safely             nature            named      recommend
# 10            manage            caprice        universal         minced
# 11            likely             strong        contented      scalloped
# 12              harm             affect           worked        oysters
# 13      interference         deservedly          wonders        urgency
# 14          rejoined                saw     quicksighted         guests
# 15     understanding             report       surrounded      occasions
# 16             silly               fine       simplicity       feelings
# 17             break       sufficiently     cheerfulness        warfare
# 18            circle          belonging         grateful          cloth
# 19        grievously             merits   recommendation           laid
# 20             elton          prospects             mine        fashion
# 21             whole             common         felicity     conviction
# 22            fitted             boasts           talker        suppers
# 23       comfortably             lively           suited    hospitality
# 24             shame          curiosity          trivial       welcomed
# 25            longer          prevailed   communications       visitors
# 26           joining         compliment           gossip         grieve
# 27             hands           achieved           school          basin
# 28              same          generally         seminary           thin
# 29           service           proposed    establishment          gruel
# 30              shew             proper        professed       thorough
# 31         attention        dissentient        sentences    approbation
# 32               ask              voice          refined      constrain
# 33              dare              perry          combine       clearing
# 34          laughing              drank          liberal          nicer
# 35            invite              bates     acquirements        propose
# 36              fish       strengthened          elegant      venturing
# 37           chicken         understood         morality           eggs
# 38             chuse            written       principles            egg
# 39               six           occasion          systems         boiled
# 40              care           included         enormous          serle
# 41                ii            mention          screwed    understands
# 42            native             letter           vanity        boiling
# 43              born              heard           honest           hurt
# 44       respectable               says        fashioned            bit
# 45       generations             prized         boarding           tart
# 46            rising             course       reasonable           ours
# 47         gentility             formed         quantity          apple
# 48          property           pleasing  accomplishments          tarts
# 49          received       irresistible             sold      preserves
# 50         education              sense            price         advise
# 51        succeeding           addition             sent        custard
# 52             small             source         scramble          glass
# 53            become         expression       themselves           wine
# 54        indisposed     congratulation        prodigies        tumbler
# 55            homely          fortunate             high          water
# 56          pursuits             regret           repute   satisfactory
# 57          brothers            partial         reckoned        sending
# 58           engaged         separation          healthy     intentions
# 59         satisfied             cooled             spot      personage
# 60            active                ill            ample   introduction
# 61            social             missed           garden          panic
# 62          entering             losing             gave         humble
# 63           militia              ennui           plenty      gratified
# 64            county  companionableness        wholesome     affability
# 65          embodied             feeble             food        treated
# 66           captain              girls              run       actually
# 67           general             energy           summer             iv
# 68         favourite       difficulties           winter          quick
# 69          military         privations          dressed        decided
# 70        introduced         convenient       chilblains       inviting
# 71         churchill           solitary           wonder    encouraging
# 72         yorkshire             female            train        telling
# 73              fell      circumstances           couple       foreseen
# 74              love        approaching           church      shrubbery
# 75         surprized             season            plain      divisions
# 76            except          hindrance         motherly         ground
# 77              full           spending         entitled       sufficed
# 78             pride           evenings       occasional         varied
# 79        importance               week          holiday       exercise
# 80         connexion         altogether         formerly       confined
# 81            offend              hours             owed       ventured
# 82           command            moments       particular         summon
# 83              bore          enjoyment             neat       valuable
# 84        proportion           apparent          parlour     privileges
# 85            estate              taken             hung       approved
# 86         dissuaded           surprize            round      confirmed
# 87              took             centre            fancy        designs
# 88          infinite           attended              win         docile
# 89     mortification             giving        sixpences        totally
# 90             threw               stay         fireside           free
# 91               due         recovering       frequently        conceit
# 92           decorum         likelihood          collect       desiring
# 93        unsuitable            ceasing             sake         guided
# 94           produce              weeks        concerned     attachment
# 95             ought        alleviation           remedy   appreciating
# 96             whose        compliments        delighted         shewed
# 97              warm         neighbours          pleased          taste
# 98             sweet             teased       contriving       strength
# 99            return          sorrowful            quiet       expected
# 100         goodness               cake         prosings      convinced
# 101           spirit                eat            women        granted
# 102       resolution            stomach        fearfully      sentiment
# 103           pursue          different      anticipated       distinct
# 104          refrain        unwholesome          looking    independent
# 105     unreasonable           regarded            close         object
# 106            anger              unfit             note          basis
# 107          missing          earnestly       requesting         esteem
# 108         luxuries              tried       respectful       attempts
# 109           former           dissuade            smith     usefulness
# 110           income               vain          request        parents
# 111            still            prevent        seventeen      questions
# 112       comparison             eating            sight     discovered
# 113         enscombe              pains         interest          truth
# 114            cease         consulting         gracious    penetration
# 115             once         apothecary          dreaded          chose
# 116       considered      gentlemanlike             fair        farther
# 117       churchills           comforts          mansion       teachers
# 118          amazing            applied          harriet        affairs
# 119            worst        acknowledge          several      naturally
# 120          bargain            against           lately        martins
# 121           poorer               bias           raised           mill
# 122            child        inclination        condition         months
# 123          expense           disagree          scholar       describe
# 124         relieved            perhaps          boarder     encouraged
# 125              boy             unless          history  talkativeness
# 126       additional         moderately          visible         amused
# 127        softening       confirmation         acquired        picture
# 128        lingering              newly          country         beings
# 129          illness               pair         happened       enjoying
# 130   reconciliation              eaten          admired       youthful
# 131          kindred         benevolent            plump     exultation
# 132          offered             nerves            bloom       parlours
# 133           charge            strange             blue          upper
# 134            frank             rumour             eyes           maid
# 135          decease             perrys            light           cows
# 136         scruples              slice             hair      alderneys
# 137       reluctance                iii          regular          welch
# 138         supposed             united         features            cow
# 139         overcome             causes        sweetness         called
# 140   considerations          residence              end          drink
# 141           wealth            measure           person          dozen
# 142             seek           families       determined       thinking
# 143          improve             horror         continue      immediate
# 144         complete            parties           struck          cause
# 145           became              terms       remarkably          wrong
# 146        desirable        fortunately         engaging       fancying
# 147          quitted          including   inconveniently       appeared
# 148            trade             parish              shy      narrative
# 149      established            donwell        unwilling           case
# 150       favourable              abbey          pushing           sink
# 151          opening               seat          shewing        forever
# 152          concern       comprehended         becoming    inspiriting
# 153          leisure       unfrequently        deference         notion
# 154       occupation         persuasion          seeming         number
# 155        pleasures          preferred       pleasantly        meaning
# 156         eighteen            fancied         admitted            led
# 157         realised            unequal        artlessly      evidently
# 158       competence            company        impressed        dislike
# 159         purchase           scarcely       appearance          share
# 160        adjoining               card         superior          walks
# 161           longed           standing            style          merry
# 162      portionless            westons          deserve          games
# 163        according             liking    encouragement          dwelt
# 164           wishes          privilege             soft       obliging
# 165         friendly         exchanging           graces          order
# 166            begun             vacant           wasted        walnuts
# 167        influence              blank         inferior       shepherd
# 168          schemes         elegancies         unworthy        purpose
# 169         tyrannic            drawing           parted           sing
# 170            youth               room           martin        singing
# 171           shaken             lovely          renting          flock
# 172    determination             thrown             farm            bid
# 173         settling                set         residing           wool
# 174             sale            goddard       creditably          spoke
# 175          forward             ladies           coarse          blush
# 176         steadily         invitation       unpolished           send
# 177          objects            fetched        intimates          goose
# 178             view            carried        knowledge         finest
# 179     accomplished           hardship         elegance         sunday
# 180           bought          grievance           notice          asked
# 181         obtained              widow           detach           nash
# 182        beginning              vicar              bad         prince
# 183              new          quadrille        introduce     richardson
# 184      probability            respect             form            sup
# 185          greater           harmless         opinions    information
# 186          unhappy              under      interesting           line
# 187          secured           untoward      undertaking           does
# 188           second            enjoyed             busy           read
# 189       delightful           uncommon         admiring            yes
# 190          judging             degree          talking          reads
# 191            truly         popularity        listening   agricultural
# 192      pleasantest            neither          forming        reports
# 193            proof              stood         betweens          books
# 194           choose        predicament             flew            lay
# 195           chosen             public          unusual         window
# 196           excite             favour           supper          seats
# 197           choice        superiority           closed          cards
# 198          tacitly          atonement            watch          aloud
# 199             heir           frighten            ready       extracts
#
#         200 words       200 words
# 0    entertaining           brain
# 1       wakefield          during
# 2         romance      expediency
# 3          forest             low
# 4            ride          fairly
# 5        kingston        doubtful
# 6           fifty      sufficient
# 7       horseback        vicarage
# 8            foot      deficiency
# 9           raise        meetings
# 10       yeomanry      foundation
# 11      precisely          weight
# 12          lower        efficacy
# 13     creditable      fastidious
# 14          above         feature
# 15          below        dispense
# 16           june          riding
# 17       birthday       conquered
# 18      fortnight               v
# 19         settle       supplying
# 20           seem        quarrels
# 21       probably           fight
# 22         repent          battle
# 23          hence       yesterday
# 24          money        agreeing
# 25            men       associate
# 26         afford           judge
# 27     beforehand           value
# 28         afloat           feels
# 29       employed             sex
# 30          stock       objection
# 31          forth            hand
# 32      diligence           wants
# 33        indoors      inducement
# 34          talks          twelve
# 35         taking           lists
# 36         scrape       regularly
# 37     acquainted          neatly
# 38       objected        arranged
# 39         follow  alphabetically
# 40            fit            rule
# 41     misfortune            list
# 42          birth            drew
# 43        careful        fourteen
# 44     associates       preserved
# 45      gentleman       expecting
# 46        station          steady
# 47         within         reading
# 48      degrading          submit
# 49          force       requiring
# 50         firmly        industry
# 51    permanently        patience
# 52      advisable      subjection
# 53        marries          failed
# 54           mere       stimulate
# 55      elizabeth          affirm
# 56       educated        persuade
# 57       ignorant        omitting
# 58         vulgar         refresh
# 59        watched          memory
# 60   fluctuations       feelingly
# 61         speech          moment
# 62       alarming           added
# 63       symptoms           charm
# 64        admirer          senses
# 65        trusted         spoiled
# 66        serious       cleverest
# 67     difficulty             ten
# 68           side         puzzled
# 69         oppose         assured
# 70    arrangement            slow
# 71           road       diffident
# 72   respectfully            cope
# 73      unfeigned        inherits
# 74    opportunity       dependent
# 75         survey       preparing
# 76          yards       receiving
# 77            eye        material
# 78         robert     matrimonial
# 79     contrasted           point
# 80      gentlemen      submitting
# 81         gained           thank
# 82     insensible           borne
# 83    voluntarily         despair
# 84        noticed            grow
# 85     gentleness           cross
# 86     admiration      wantonness
# 87       remained          plague
# 88        minutes        vexation
# 89           kept         quarter
# 90        waiting   possibilities
# 91        running         pretend
# 92        smiling          genius
# 93        flutter     foretelling
# 94        compose       flatterer
# 95      happening           worse
# 96         chance      undesigned
# 97        towards       ignorance
# 98         forgot          hourly
# 99         morrow        flattery
# 100        happen           learn
# 101   undoubtedly      presenting
# 102      compared     inferiority
# 103        entire         venture
# 104        expect            gain
# 105      clownish          places
# 106           air         belongs
# 107      imagined   uncomfortable
# 108       confess        mistaken
# 109        nearer       doctrines
# 110     mortified            tend
# 111       genteel           adapt
# 112    repeatedly      rationally
# 113     specimens       varieties
# 114          bred          polish
# 115        seeing         anxious
# 116    perceiving          lament
# 117     wondering         attempt
# 118       awkward            deny
# 119        abrupt          seldom
# 120   uncouthness           hazle
# 121        wholly       brilliant
# 122   unmodulated     countenance
# 123       compare      complexion
# 124       hundred          height
# 125       plainly            size
# 126      carrying            firm
# 127      speaking         upright
# 128        silent          glance
# 129         forty           hears
# 130         makes           gives
# 131         grows      loveliness
# 132       glaring             add
# 133    disgusting      personally
# 134      loudness         appears
# 135    coarseness            lies
# 136   awkwardness           dread
# 137       becomes         equally
# 138      passable           stout
# 139    detestable      confidence
# 140         later          kinder
# 141      solemnly           truer
# 142      guessing       qualities
# 143    completely            lead
# 144         gross         lasting
# 145   inattentive         blunder
# 146   appearances            errs
# 147        profit           angel
# 148     engrosses          spleen
# 149    forgetting          brings
# 150       inquire            john
# 151          book           blind
# 152        market      frightened
# 153      thriving          unjust
# 154        thrive          unkind
# 155    illiterate          excuse
# 156       disturb         liberty
# 157      remember        consider
# 158        answer        somewhat
# 159         grave         hinting
# 160   displeasure           arise
# 161        itself      discussion
# 162          held       supposing
# 163       pattern   inconvenience
# 164      openness     apprehended
# 165     quickness     accountable
# 166     bluntness        approves
# 167         likes        province
# 168        humour          advice
# 169        copied         remains
# 170     downright            fate
# 171    commanding         alarmed
# 172         suits          outcry
# 173        figure         sincere
# 174       copying         excited
# 175    sufferable         anxiety
# 176      contrary          gently
# 177         model        declares
# 178         seems           cared
# 179         grown      hereabouts
# 180        design           tempt
# 181  ingratiating        creating
# 182      softness          slight
# 183       strikes           state
# 184        softer          assure
# 185      repeated         conceal
# 186      personal      respecting
# 187        praise         destiny
# 188       justice       suspected
# 189       blushed      transition
# 190         fixed         weather
# 191       driving         surmise
# 192      palpably              vi
# 193      probable       direction
# 194        feared       decidedly
# 195       predict      hesitation
# 196      equalled       following
# 197          date       assurance
# 198          plan           hints
# 199       entered       confident

# %% [markdown]
# We will use the function in the Natural Language Processing with Python textbook on page 228 to create a feature generator that uses the 2000 most frequent words list and indicates whether or not each word is present in the text as a feature.

# %%
def document_features(document): 
    document_words = set(document) 
    features = {}
    for word in word_features:
        features['contains({})'.format(word)] = (word in document_words)
    return features

# %% [markdown]
# Let's test it on the full Blake text...

# %%
features = document_features(blake)
list(features.items())[:20]
# Out:
# [('contains(emma)', False),
#  ('contains(by)', True),
#  ('contains(jane)', False),
#  ('contains(austen)', False),
#  ('contains(volume)', False),
#  ('contains(i)', True),
#  ('contains(chapter)', False),
#  ('contains(woodhouse)', False),
#  ('contains(handsome)', False),
#  ('contains(clever)', False),
#  ('contains(and)', True),
#  ('contains(rich)', True),
#  ('contains(with)', True),
#  ('contains(a)', True),
#  ('contains(comfortable)', False),
#  ('contains(home)', True),
#  ('contains(happy)', True),
#  ('contains(disposition)', False),
#  ('contains(seemed)', True),
#  ('contains(to)', True)]

# %% [markdown]
# ### Create Test Train Dataset
#
# Now we need to create a list of all text segments from both Austen and Blake and shuffle them to create the text corpus that we will use to train and test our classifier model.

# %%
documents=austen1+blake1

# %%
import random
random.shuffle(documents)
featuresets = [(document_features(d), c) for (d,c) in documents]
len(featuresets)
# Out:
# 373

# %% [markdown]
# Next we split our dataset into test and train sections, train our classifier on the training set, and check the accuracy of our model on the test set.

# %%
train_set, test_set = featuresets[:100], featuresets[100:]
classifier = nltk.NaiveBayesClassifier.train(train_set)

# %%
print(nltk.classify.accuracy(classifier, test_set))
# Out:
# 0.9706959706959707

# %% [markdown]
# It is very easy to for NLKT to distinguish between Austen and Blake. Let's try more authors.

# %% [markdown]
# ## Adding Bryant

# %%
bryant = nltk.corpus.gutenberg.words('bryant-stories.txt')
bryant = [word.lower() for word in bryant if word.isalpha()]
bryant1=[]
for i in range(46):
    bryant1.append([bryant[i*1000:(i+1)*1000],'br'])
len(bryant)
# Out:
# 46611

# %%
abb=austen+blake+bryant
all_words = nltk.FreqDist(w.lower() for w in abb)
word_features = list(all_words)[:2000] 

documents=austen1+blake1+bryant1

# %%
random.shuffle(documents)
featuresets = [(document_features(d), c) for (d,c) in documents]
len(featuresets)
# Out:
# 419

# %%
train_set, test_set = featuresets[:100], featuresets[100:]
classifier = nltk.NaiveBayesClassifier.train(train_set)

# %%
print(nltk.classify.accuracy(classifier, test_set))
# Out:
# 0.9843260188087775

# %% [markdown]
# We still get even better results in distinguishing between Austen, Blake, and Braynt.

# %% [markdown]
# ## Adding Burgess

# %%
burgess = nltk.corpus.gutenberg.words('burgess-busterbrown.txt')
burgess = [word.lower() for word in burgess if word.isalpha()]
burgess1=[]
for i in range(16):
    burgess1.append([burgess[i*1000:(i+1)*1000],'bu'])
len(burgess)
# Out:
# 16327

# %%
abbb=austen+blake+bryant+burgess
all_words = nltk.FreqDist(w.lower() for w in abbb)
word_features = list(all_words)[:2000] 

documents=austen1+blake1+bryant1+burgess1

# %%
random.shuffle(documents)
featuresets = [(document_features(d), c) for (d,c) in documents]
len(featuresets)
# Out:
# 435

# %%
train_set, test_set = featuresets[:100], featuresets[100:]
classifier = nltk.NaiveBayesClassifier.train(train_set)
print(nltk.classify.accuracy(classifier, test_set))
# Out:
# 0.9402985074626866

# %% [markdown]
# Accuracy declined a bit, but we are still in the mid 90's.
#
# Let's see what features are most important in training our model...

# %%
classifier.show_most_informative_features(25)
# Out:
# Most Informative Features
#           contains(much) = False              bl : au     =     52.8 : 1.0
#            contains(eat) = True               bu : au     =     44.0 : 1.0
#          contains(below) = True               bu : au     =     44.0 : 1.0
#         contains(chosen) = True               bu : au     =     44.0 : 1.0
#          contains(stout) = True               bu : au     =     44.0 : 1.0
#        contains(becomes) = True               bu : au     =     44.0 : 1.0
#           contains(free) = True               bl : au     =     29.3 : 1.0
#           contains(been) = False              bl : au     =     29.3 : 1.0
#       contains(youthful) = True               bl : au     =     29.3 : 1.0
#           contains(soft) = True               bl : au     =     29.3 : 1.0
#           contains(tear) = True               bl : au     =     29.3 : 1.0
#           contains(goes) = True               bu : au     =     26.4 : 1.0
#           contains(mild) = True               bl : au     =     24.6 : 1.0
#           contains(sing) = True               bl : au     =     24.6 : 1.0
#         contains(ground) = True               bu : au     =     18.9 : 1.0
#       contains(wherever) = True               bu : au     =     18.9 : 1.0
#           contains(hard) = True               bu : au     =     18.9 : 1.0
#            contains(run) = True               bu : au     =     18.9 : 1.0
#         contains(taught) = True               bu : au     =     18.9 : 1.0
#         contains(brings) = True               bl : au     =     17.6 : 1.0
#              contains(s) = False              bl : au     =     17.6 : 1.0
#        contains(healthy) = True               bl : au     =     17.6 : 1.0
#          contains(angel) = True               bl : au     =     17.6 : 1.0
#         contains(garden) = True               bl : au     =     17.6 : 1.0
#          contains(brain) = True               bl : au     =     17.6 : 1.0

# %% [markdown]
# It appears that a text that does not contain the word 'much' is 52 times more likely
# to be by Blake than by Austen, while a text that contains the word "eat", "below", "chosen", "stout" or "becomes" are each 44 times more likely to be by Burgess than by Austen.  Texts that contain the word 'free', 'youthful', 'soft' or "tear" are each 29 times more likely to be by Blake than by Austen.

# %% [markdown]
# ## Adding Carroll

# %%
carroll = nltk.corpus.gutenberg.words('carroll-alice.txt')
carroll = [word.lower() for word in carroll if word.isalpha()]
carroll1=[]
for i in range(27):
    carroll1.append([carroll[i*1000:(i+1)*1000],'ca'])
len(carroll)
# Out:
# 27333

# %%
abbbc=austen+blake+bryant+burgess+carroll
all_words = nltk.FreqDist(w.lower() for w in abbbc)
word_features = list(all_words)[:2000] 

documents=austen1+blake1+bryant1+burgess1+carroll1

# %%
random.shuffle(documents)
featuresets = [(document_features(d), c) for (d,c) in documents]
len(featuresets)
# Out:
# 462

# %%
train_set, test_set = featuresets[:100], featuresets[100:]
classifier = nltk.NaiveBayesClassifier.train(train_set)
print(nltk.classify.accuracy(classifier, test_set))
# Out:
# 0.8839779005524862

# %% [markdown]
# By adding Carroll accuracy declined significantly. This is probably because we now are using a smaller percent (100/462) of our corpus for training and we are adding more complexity by adding more categories to classify into.  Let's keep adding more authors and see what happens.

# %%
classifier.show_most_informative_features(25)
# Out:
# Most Informative Features
#       contains(youthful) = True               bl : au     =     41.0 : 1.0
#         contains(forgot) = True               bl : au     =     41.0 : 1.0
#           contains(mild) = True               bl : au     =     41.0 : 1.0
#            contains(had) = False              bl : au     =     41.0 : 1.0
#           contains(sing) = True               bl : au     =     41.0 : 1.0
#          contains(glass) = True               bl : au     =     41.0 : 1.0
#          contains(walks) = True               bl : au     =     41.0 : 1.0
#         contains(gently) = True               bl : au     =     41.0 : 1.0
#             contains(by) = False              bu : au     =     34.2 : 1.0
#        contains(noticed) = True               ca : au     =     31.9 : 1.0
#          contains(would) = False              bl : au     =     24.6 : 1.0
#          contains(birth) = True               bl : au     =     24.6 : 1.0
#         contains(rising) = True               bl : au     =     24.6 : 1.0
#          contains(sleep) = True               bl : au     =     24.6 : 1.0
#          contains(water) = True               bl : au     =     24.6 : 1.0
#          contains(could) = False              bl : au     =     24.6 : 1.0
#      contains(decidedly) = True               ca : au     =     22.8 : 1.0
#           contains(grow) = True               ca : au     =     22.8 : 1.0
#          contains(drink) = True               ca : au     =     22.8 : 1.0
#          contains(eaten) = True               bu : au     =     20.5 : 1.0
#          contains(black) = True               bu : au     =     20.5 : 1.0
#         contains(manage) = True               ca : au     =     19.1 : 1.0
#         contains(winter) = True               bl : au     =     17.6 : 1.0
#           contains(book) = True               bl : au     =     17.6 : 1.0
#       contains(included) = True               bl : au     =     17.6 : 1.0

# %% [markdown]
# Common words that indicate that a text is more likely to have been written by Blake are "youthful", "forgot", "mild", "sing", "glass", "walks",  and "gently" which each indicate a text is 41 times more likely to have been written by Blake than Austen. For Burgess, indicator words are "eaten" and "black", and for Austen, "had", "by", "could" and "would".

# %% [markdown]
# ## Adding Chesterson

# %%
chesterson = nltk.corpus.gutenberg.words('chesterton-ball.txt')+nltk.corpus.gutenberg.words('chesterton-brown.txt')+nltk.corpus.gutenberg.words('chesterton-thursday.txt')
chesterson = [word.lower() for word in chesterson if word.isalpha()]
chesterson1=[]
for i in range(214):
    chesterson1.append([chesterson[i*1000:(i+1)*1000],'ch'])
len(chesterson)
# Out:
# 214692

# %%
abbbcc=austen+blake+bryant+burgess+carroll+chesterson
all_words = nltk.FreqDist(w.lower() for w in abbbcc)
word_features = list(all_words)[:2000] 

documents=austen1+blake1+bryant1+burgess1+carroll1+chesterson1

# %%
random.shuffle(documents)
featuresets = [(document_features(d), c) for (d,c) in documents]
len(featuresets)
# Out:
# 676

# %% [markdown]
# Since we now have 676 texts, let's increase our training set to keep it at about 25% of the corpus.

# %%
train_set, test_set = featuresets[:170], featuresets[170:]
classifier = nltk.NaiveBayesClassifier.train(train_set)
print(nltk.classify.accuracy(classifier, test_set))
# Out:
# 0.8853754940711462

# %% [markdown]
# Still at about 88%.

# %%
classifier.show_most_informative_features(25)
# Out:
# Most Informative Features
#        contains(healthy) = True               bl : au     =     45.5 : 1.0
#         contains(rising) = True               bl : au     =     45.5 : 1.0
#           contains(sing) = True               bl : au     =     45.5 : 1.0
#          contains(bears) = True               bl : au     =     45.5 : 1.0
#          contains(drink) = True               bl : au     =     45.5 : 1.0
#           contains(tear) = True               bl : au     =     45.5 : 1.0
#          contains(grows) = True               bl : au     =     45.5 : 1.0
#        contains(parents) = True               bl : au     =     45.5 : 1.0
#            contains(eat) = True               bu : au     =     31.9 : 1.0
#          contains(tears) = True               bl : ch     =     30.5 : 1.0
#         contains(winter) = True               bl : ch     =     30.5 : 1.0
#       contains(youthful) = True               bl : ch     =     30.5 : 1.0
#           contains(pray) = True               bl : ch     =     30.5 : 1.0
#           contains(bore) = True               bl : ch     =     30.5 : 1.0
#        contains(reading) = True               bl : ch     =     30.5 : 1.0
#          contains(sweet) = True               bl : ch     =     30.5 : 1.0
#         contains(smiles) = True               bl : ch     =     30.5 : 1.0
#          contains(apple) = True               bl : ch     =     30.5 : 1.0
#        contains(removed) = True               bl : ch     =     30.5 : 1.0
#         contains(wishes) = True               bl : ch     =     30.5 : 1.0
#        contains(admired) = True               bl : ch     =     30.5 : 1.0
#         contains(former) = True               bl : ch     =     30.5 : 1.0
#           contains(free) = True               bl : au     =     27.3 : 1.0
#         contains(brings) = True               bl : au     =     27.3 : 1.0
#           contains(flow) = True               bl : au     =     27.3 : 1.0

# %% [markdown]
# ## Adding the rest of the authors

# %%
edgeworth = nltk.corpus.gutenberg.words('edgeworth-parents.txt')
edgeworth = [word.lower() for word in edgeworth if word.isalpha()]
edgeworth1=[]
for i in range(170):
    edgeworth1.append([edgeworth[i*1000:(i+1)*1000],'ed'])
len(edgeworth)
# Out:
# 170737

# %%
melville = nltk.corpus.gutenberg.words('melville-moby_dick.txt')
melville = [word.lower() for word in melville if word.isalpha()]
melville1=[]
for i in range(218):
    melville1.append([melville[i*1000:(i+1)*1000],'me'])
len(melville)
# Out:
# 218361

# %%
shakespeare = nltk.corpus.gutenberg.words('shakespeare-caesar.txt')+nltk.corpus.gutenberg.words('shakespeare-hamlet.txt')+nltk.corpus.gutenberg.words('shakespeare-macbeth.txt')
shakespeare = [word.lower() for word in shakespeare if word.isalpha()]
shakespeare1=[]
for i in range(69):
    shakespeare1.append([shakespeare[i*1000:(i+1)*1000],'sh'])
len(shakespeare)
# Out:
# 69340

# %%
whitman = nltk.corpus.gutenberg.words('whitman-leaves.txt')
whitman = [word.lower() for word in whitman if word.isalpha()]
whitman1=[]
for i in range(126):
    whitman1.append([whitman[i*1000:(i+1)*1000],'wh'])
len(whitman)
# Out:
# 126276

# %%
abbbccemsw=austen+blake+bryant+burgess+carroll+chesterson+edgeworth+melville+shakespeare+whitman
all_words = nltk.FreqDist(w.lower() for w in abbbccemsw)
word_features = list(all_words)[:2000] 

documents=austen1+blake1+bryant1+burgess1+carroll1+chesterson1+edgeworth1+melville1+shakespeare1+whitman1

# %%
random.shuffle(documents)
featuresets = [(document_features(d), c) for (d,c) in documents]
len(featuresets)
# Out:
# 1259

# %%
train_set, test_set = featuresets[:320], featuresets[320:]
classifier = nltk.NaiveBayesClassifier.train(train_set)
print(nltk.classify.accuracy(classifier, test_set))
# Out:
# 0.9084132055378061

# %% [markdown]
# Very nice results!

# %%
classifier.show_most_informative_features(40)
# Out:
# Most Informative Features
#            contains(her) = False              bu : au     =     58.9 : 1.0
#         contains(farmer) = True               bu : au     =     58.9 : 1.0
#           contains(mild) = True               bl : au     =     56.1 : 1.0
#           contains(very) = False              bl : au     =     56.1 : 1.0
#           contains(have) = False              sh : au     =     39.3 : 1.0
#        contains(herself) = True               ca : ch     =     36.7 : 1.0
#            contains(mrs) = True               au : ch     =     36.2 : 1.0
#          contains(angel) = True               bl : au     =     33.7 : 1.0
#           contains(seek) = True               bl : au     =     33.7 : 1.0
#           contains(wool) = True               bl : au     =     33.7 : 1.0
#           contains(sing) = True               bl : au     =     33.7 : 1.0
#          contains(tears) = True               bl : ch     =     33.3 : 1.0
#         contains(lovely) = True               bl : ch     =     33.3 : 1.0
#          contains(sweet) = True               bl : ch     =     33.3 : 1.0
#         contains(smiles) = True               bl : ch     =     33.3 : 1.0
#          contains(sleep) = True               bl : ch     =     33.3 : 1.0
#         contains(sorrow) = True               bl : ch     =     33.3 : 1.0
#            contains(joy) = True               bl : ch     =     33.3 : 1.0
#            contains(had) = False              wh : au     =     31.5 : 1.0
#           contains(food) = True               br : au     =     30.3 : 1.0
#           contains(size) = True               ca : au     =     30.3 : 1.0
#           contains(fill) = True               wh : au     =     28.3 : 1.0
#            contains(tis) = True               sh : au     =     28.1 : 1.0
#             contains(iv) = True               bu : au     =     25.2 : 1.0
#        contains(stomach) = True               bu : au     =     25.2 : 1.0
#            contains(shy) = True               bu : au     =     25.2 : 1.0
#         contains(plenty) = True               bu : au     =     25.2 : 1.0
#           contains(fish) = True               bu : au     =     25.2 : 1.0
#          contains(watch) = True               bu : au     =     25.2 : 1.0
#            contains(cow) = True               bu : au     =     25.2 : 1.0
#     contains(surprising) = True               bu : au     =     25.2 : 1.0
#        contains(forever) = True               bu : au     =     25.2 : 1.0
#            contains(bit) = True               bu : au     =     25.2 : 1.0
#         contains(eating) = True               bu : au     =     25.2 : 1.0
#             contains(an) = False              bu : ch     =     25.0 : 1.0
#         contains(forgot) = True               bu : ch     =     25.0 : 1.0
#     contains(frightened) = True               bu : ch     =     25.0 : 1.0
#            contains(not) = False              bu : ch     =     25.0 : 1.0
#          contains(could) = False              bl : au     =     24.0 : 1.0
#           contains(goes) = True               ca : au     =     23.6 : 1.0

# %% [markdown]
# ## YouTube Link
